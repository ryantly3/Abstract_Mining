# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('WGS_abstracts.txt', sep = '\t', set_indexnames = ['Project ID','Title','Abstract','Runs'])
df['Abstract']
# Out:
# 0                    Isolation of phages from waste water
# 1       Biogeochemical cycling links between terrestri...
# 2
# 3                                           none provided
# 4       Diamante Lake is a multi-extreme environment l...
# 5       Metagenomics of anaerobic wastewater microbial...
# 6                                            workshop aau
# 7
# 8       Metagenomic analysis of highly acidic (pH 0-1)...
# 9       Identifying viral communities during a global ...
# 10      In this study we sought to explore the fibroly...
# 11
# 12                     Metagenomic data for CG-3 and SG-1
# 13
# 14      Recovery of variola virus through targeted enr...
# 15      Sequencing of microbial communities from the C...
# 16      Metagenomic raw reads from acidic hot spring m...
# 17      Sequencing of microbial communities from the C...
# 18
# 19      Microbiomes isolated from Korean fermented foo...
# 20
# 21      Metagenome sequencing of total DNA extracted f...
# ...

# %%
df.replace(r'^\s+$', 'None', regex=True)
# Out:
#      Project ID                                              Title  \
# 0     SRP099026               sludge metagenome Raw sequence reads
# 1     SRP107999  Aqueous microbial communities from the Delawar...
# 2     SRP080517  Grasslands soil microbial communities from the...
# 3     SRP007817  Hoatzin crop microbiome epithelium fraction 12...
# 4     ERP021394  Environmental alkali multi-extreme Diamante La...
# 5     SRP096603  Active sludge microbial communities of municip...
# 6     ERP006694                                     test sequences
# 7     SRP100041  Marine microbial communities from the Southern...
# 8     SRP006444  Community genomic analysis of an extremely aci...
# 9     SRP104952  Marine viral communities from the Global Malas...
# 10    SRP041163                 Bovine rumen microbiome Metagenome
# 11    SRP099977  Freshwater microbial communities from Crystal ...
# 12    SRP059473    Dechlorination Culture CG-3 and SG-1 Metagenome
# ...
