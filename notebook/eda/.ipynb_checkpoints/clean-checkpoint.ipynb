# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
df = pd.read_csv('WGS_abstracts.txt', sep = '\t', names = ['Project ID','Title','Abstract','Runs'])
df.set_index('Project ID', inplace=True)

df = df.replace(r'^\s+$', 'None', regex=True)
df = df.replace(r'none provided', 'None', regex=True)
df = df.replace(r'â€˜', '', regex=True)
df = df.replace(r'â€™', '', regex=True)
df = df.replace(r'\.(?!\d)', '', regex=True)
df = df.replace(r',', '', regex=True)
df = df.replace(r'\(', '', regex=True)
df = df.replace(r'\)', '', regex=True)
df = df.replace(np.nan, '')
print(df)

abstracts = df['Abstract']
# Out:
#                                                         Title  \
# Project ID
# SRP099026                sludge metagenome Raw sequence reads
# SRP107999   Aqueous microbial communities from the Delawar...
# SRP080517   Grasslands soil microbial communities from the...
# SRP007817   Hoatzin crop microbiome epithelium fraction 12...
# ERP021394   Environmental alkali multi-extreme Diamante La...
# SRP096603   Active sludge microbial communities of municip...
# ERP006694                                      test sequences
# SRP100041   Marine microbial communities from the Southern...
# SRP006444   Community genomic analysis of an extremely aci...
# SRP104952   Marine viral communities from the Global Malas...
# SRP041163                  Bovine rumen microbiome Metagenome
# SRP099977   Freshwater microbial communities from Crystal ...
# SRP059473     Dechlorination Culture CG-3 and SG-1 Metagenome
# SRP081889   Freshwater microbial communities from Trout Bo...
# SRP091673                          17th century variola virus
# SRP104826   Estuarine microbial communities from the Colum...
# SRP041649                        Acidic hot spring Metagenome
# SRP098105   Estuarine microbial communities from the Colum...
# SRP081953   Freshwater microbial communities from Trout Bo...
# SRP003198                     Metagenome isolated from kimchi
# SRP081962   Freshwater microbial communities from Trout Bo...
# SRP104928   Freshwater sediment microbial communities from...
# SRP066089   Deep metagenome and transcriptome analyses of ...
# SRP099516   Avena fatua rhizosphere microbial communities ...
# SRP098069   Groundwater microbial communities from the Col...
# SRP081480   Wastewater treatment Type I Accumulibacter com...
# SRP092476   Synthetic human gut microbiota 14 species asse...
# SRP100226   Bog forest soil microbial communities from Cal...
# SRP077422   Marine microbial communities from expanding ox...
# SRP100314   Freshwater lake sediment microbial communities...
# ...                                                       ...
# SRP103438   Freshwater sediment methanotrophic microbial c...
# SRP100025   Freshwater microbial communities from Crystal ...
# SRP046072   Pit mud of Chinese liqour fermentation reactor...
# SRP080037   Marine microbial communities from the Deep Pac...
# SRP080066   Marine microbial communities from the Deep Atl...
# SRP104998   Groundwater sediment microbial communities fro...
# SRP080527   Arabidopsis root microbial communities from th...
# SRP103417   Freshwater sediment methanotrophic microbial c...
# SRP090270                          soil metagenome Metagenome
# ERP022764   A case of hepatic brucelloma studied by next g...
# SRP116264                    Human Milk Microbiome Metagenome
# SRP099916   Freshwater lake microbial communities from Lak...
# SRP100267   Soil microbial communities from Arlington Agri...
# SRP024366   RNA and DNA based 16S rRNA analysis of marine ...
# ERP021528   study of microbial communities of a lake durin...
#
# [5385 rows x 3 columns]

# %%
cvec = CountVectorizer(stop_words='english', min_df=1, max_df=.25, ngram_range=(1,2))

# %%
from itertools import islice
cvec.fit(abstracts)
list(islice(cvec.vocabulary_.items(), 20))
# Out:
# [('isolation', 993),
#  ('phages', 1355),
#  ('water', 1967),
#  ('biogeochemical', 239),
#  ('cycling', 474),
#  ('links', 1064),
#  ('terrestrial', 1846),
#  ('marine', 1099),
#  ('systems', 1819),
#  ('biogeochemical cycling', 241),
#  ('cycling links', 477),
#  ('links terrestrial', 1065),
#  ('terrestrial marine', 1847),
#  ('marine systems', 1104),
#  ('lake', 1024),
#  ('multi', 1231),
#  ('extreme', 703),
#  ('environment', 649),
#  ('located', 1073),
#  ('developing', 535)]

# %%
cvec_counts = cvec.transform(abstracts)
cvec_counts.shape
# Out:
# (5385, 2000)

# %%
occ = np.asarray(cvec_counts.sum(axis=0)).ravel().tolist()
counts_df = pd.DataFrame({'term': cvec.get_feature_names(), 'occurrences': occ})
counts_df.sort_values(by='occurrences', ascending=False).head(20)
# Out:
#                        term  occurrences
# 359             communities         1182
# 1650             sequencing         1085
# 374               community          891
# 1762                  study          876
# 1136            metagenomic          848
# 1180  microbial communities          809
# 1605                samples          770
# 1702                   soil          672
# 284                  carbon          613
# 569                     dna          609
# 1596                 sample          594
# 1131             metagenome          592
# 128                analysis          539
# 1929                  using          522
# 854                     gut          473
# 208               bacterial          469
# 565               diversity          457
# 1199             microbiota          437
# 1195             microbiome          434
# 343               collected          382

# %%
transformer = TfidfTransformer()
transformed_weights = transformer.fit_transform(cvec_counts)

# %%
weights = np.asarray(transformed_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': cvec.get_feature_names(), 'weight': weights})
weights_df.sort_values(by='weight', ascending=False).head(20)
# Out:
#                        term    weight
# 359             communities  0.024028
# 1650             sequencing  0.021107
# 1180  microbial communities  0.019875
# 1136            metagenomic  0.018313
# 1762                  study  0.017185
# 374               community  0.017013
# 1702                   soil  0.016432
# 1131             metagenome  0.016332
# 1605                samples  0.013851
# 128                analysis  0.013447
# 284                  carbon  0.013274
# 1596                 sample  0.011570
# 1195             microbiome  0.011022
# 1148           metagenomics  0.010296
# 474                 cycling  0.009889
# 569                     dna  0.009829
# 208               bacterial  0.009608
# 854                     gut  0.009247
# 565               diversity  0.009211
# 1628               sediment  0.009073

# %%
x_train = transformed_weights
mu = x_train.mean(axis=0)
U,s,V = np.linalg.svd(x_train - mu, full_matrices=False)
Zpca = np.dot(x_train - mu, V.transpose())

Rpca = np.dot(Zpca[:,:2], V[:2,:]) + mu    # reconstruction

# %%
err = np.sum(np.asarray(x_train-Rpca)**2)/Rpca.shape[0]/Rpca.shape[1]
print(err)

# %%
plt.scatter([Zpca[:2000,0]], [Zpca[:2000,1]])
plt.show()
